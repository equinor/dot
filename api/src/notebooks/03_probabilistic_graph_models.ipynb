# %%
import sys

sys.path.append("../pgm")
from probabilistic_graph_models import ProbGraphModel  # , read_model
# from models.bn_cancer_model import cancer_model
# from models.id_used_car_buyer import used_car_buyer

# %%
model = ProbGraphModel.read_model("models/bn_cancer_model.yaml")

# %%
# model = ProbGraphModel(
#     name="cancer model",
#     variables=cancer_model.variables,
#     graph=cancer_model.graph,
#     potentials=cancer_model.potentials
# )

# %%
print(model.name)

# %%
model.print_variables()

# %%
model.print_nodes()

# %%
model.print_arcs()

# %%
model.print_potentials()

# %%
print(model.get_potential_by_name("Cancer"))

# %%
print(model.get_variable_by_name("Cancer"))

# %%
# model = ProbGraphModel(
#     name="used car buyer model",
#     variables=used_car_buyer.variables,
#     graph=used_car_buyer.graph,
#     potentials=used_car_buyer.potentials
# )
model = ProbGraphModel.read_model("models/id_used_car_buyer.yaml")

# %%
print(model.name)

# %%
model.print_variables()

# %%
model.print_nodes()

# %%
model.print_arcs()

# %%
model.print_potentials()

# %%
print(model.get_potential_by_name("Testing costs"))

# %%
print(model.get_variable_by_name("Test result"))

# %%
model.potential_to_xarray("Testing costs")

# %%
xarr =  model.potential_to_xarray("Test result")
xarr.sel(Test_decision="yes", Car_state="lemon")
